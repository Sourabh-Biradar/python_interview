# %%
# python interview

# tuple methods

# %% [markdown]
# count
#
# index
#
# in
#
# arithmatic ops
#
# '*' : repeats elements by specified number

# %%
tup = (3,)

i = (3)

type(tup) , type(i)
# Out:
# (tuple, int)

# %%
t = (3,'a',9.11,3)

# %%
t.count(3)
# Out:
# 2

# %%
t.index('a')
# Out:
# 1

# %%
9.11 in t
# Out:
# True

# %%
t + (5,6)
# Out:
# (3, 'a', 9.11, 3, 5, 6)

# %%
t * 2
# Out:
# (3, 'a', 9.11, 3, 3, 'a', 9.11, 3)
